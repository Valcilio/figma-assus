# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns
import sys
sys.path.insert(0, os.environ.get('SRC_FIGMA_PATH'))


from cryptocurrencyetl import CryptocurrencyEtl
import context as c
from dataanalysis import DataAnalysis

# %% [markdown]
# # 1.0. Data Extraction

# %%
# crypto = 'BTC'
# market_curr = 'USD'
# api_key = os.environ.get('TOKEN_FIGMA_CRYPTO_KEY')

# crypt_etl = CryptocurrencyEtl(crypto=crypto, market_curr=market_curr, api_key=api_key)

# #crypt_etl.test_market_curr()
# #crypt_etl.test_crypto()

# df_btc_usd = crypt_etl.run()

# %%
df_btc_usd = pd.read_csv(c.DATA_PROC_FLD / 'btc_usd_proc.csv')

# %% [markdown]
# # 2.0. Data Analysis

# %%
analy = DataAnalysis(df_btc_usd, date_col='timestamp', figsize=(20, 12))

# %% [markdown]
# ## 2.1. Statistical Description

# %%
analy.statistical_description()
# Out:
#   attributes          mean        median           std         min  \
# 0       open  28562.440940  30306.575000  18631.241868  4800.01000
# 1       high  29360.903560  31394.450000  19149.279388  5365.42000
# 2        low  27646.317530  29288.285000  18023.135373  3782.13000
# 3      close  28575.082040  30306.585000  18623.211023  4800.00000
# 4     volume  65094.226786  55546.057727  38507.500476  3139.84807
#
#              max          range      skew   kurtosis
# 0   67525.820000   62725.810000  0.239380  -1.414270
# 1   69000.000000   63634.580000  0.226920  -1.433496
# 2   66222.400000   62440.270000  0.253444  -1.393578
# 3   67525.830000   62725.830000  0.238616  -1.413078
# 4  402201.673764  399061.825694  2.609826  12.181748

# %% [markdown]
# ## 2.2. Temporal Estability

# %% [markdown]
# ### 2.2.1. Year

# %%
analy.annual_stability(y=['close', 'open'], figsize=(24, 10))

# %% [markdown]
# ### 2.2.2. Monthly

# %%
analy.monthly_stability(y=['close', 'high'], figsize=(24, 10))

# %% [markdown]
# ### 2.2.3. Daily

# %%
analy.daily_stability(last_days=300, y=['close', 'high'], figsize=(24, 10))

# %% [markdown]
# ## 2.3. Outlier Identification

# %%
analy.all_temporal_outlier_detector_boxplots()

# %% [markdown]
# ### 2.3.1. Year

# %%
analy.outlier_analysis_boxplot(titlesize=25, x='Year', y='close')

# %% [markdown]
# ### 2.3.2. Month

# %%
analy.outlier_analysis_boxplot(titlesize=25, x='Month', y='close')

# %% [markdown]
# ### 2.3.3. Day of Month

# %%
analy.outlier_analysis_boxplot(titlesize=25, x='Day of Month', y='close')

# %% [markdown]
# ### 2.3.4. Day of Week

# %%
analy.outlier_analysis_boxplot(titlesize=25, x='Day of Week', y='close')

# %% [markdown]
# ## 2.4. Distribution

# %%
df_btc_usd.hist(figsize=(24, 13));

# %% [markdown]
# ## 2.5. Nature Transformation Effect

# %% [markdown]
# # 3.0. Data Preparation

# %% [markdown]
# ## 3.1. Adjust Dataset

# %% [markdown]
# ## 3.2. Nature Transformation

# %% [markdown]
# # 4.0. Machine Learning Model

# %% [markdown]
# ## 4.1. SARIMAX

# %% [markdown]
# ### 4.1.1. Modeling

# %% [markdown]
# ### 4.1.2. Validation

# %% [markdown]
# ## 4.2. ARIMA

# %% [markdown]
# ### 4.2.1. Modeling

# %% [markdown]
# ### 4.2.2. Validation

# %% [markdown]
# ## 4.3. Saving Model
