# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sys
sys.path.insert(0, os.environ.get('SRC_FIGMA_PATH'))


from cryptocurrencyetl import CryptocurrencyEtl
import context as c
from dataanalysis import DataAnalysis

# %% [markdown]
# # 1.0. Data Extraction

# %%
crypto = 'BTC'
market_curr = 'USD'
api_key = os.environ.get('TOKEN_FIGMA_CRYPTO_KEY')

crypt_etl = CryptocurrencyEtl(crypto=crypto, market_curr=market_curr, api_key=api_key)

#crypt_etl.test_market_curr()
#crypt_etl.test_crypto()

df_btc_usd = crypt_etl.run()
# Out:
# 2022-06-13 07:41:09,255 (INFO)	||| Initing extract of ETL to obtain BTC historical data in USD value!
# 2022-06-13 07:41:10,243 (INFO)	||| Initing data transform of BTC historical data!
# 2022-06-13 07:41:10,257 (INFO)	||| ETL finished!

# %% [markdown]
# # 2.0. Data Analysis

# %%
analy = DataAnalysis(df_btc_usd)

# %%
check_index_dtype = pd.DataFrame(df_btc_usd.index).select_dtypes('datetime64[ns]')
check_index_dtype.shape[1]
# Out:
# 1

# %% [markdown]
# ## 2.1. Statistical Description

# %%
analy.statistical_description()
# Out:
#   attributes          mean        median           std          min  \
# 0       open  28525.823120  30306.575000  18655.290383  4800.010000
# 1       high  29322.798110  31394.450000  19174.535113  5365.420000
# 2        low  27617.185600  29288.285000  18044.737205  3782.130000
# 3      close  28542.615380  30306.585000  18646.464970  4800.000000
# 4     volume  64549.530025  55341.317023  37636.772840  6865.239989
#
#              max          range      skew   kurtosis
# 0   67525.820000   62725.810000  0.241594  -1.417800
# 1   69000.000000   63634.580000  0.229149  -1.437062
# 2   66222.400000   62440.270000  0.254727  -1.396934
# 3   67525.830000   62725.830000  0.240217  -1.416561
# 4  402201.673764  395336.433775  2.627800  12.862362

# %% [markdown]
# ## 2.2. Temporal Estability

# %% [markdown]
# ### 2.2.1. Year

# %%
analy.annual_stability(y=['close', 'open'], figsize=(24, 10))

# %% [markdown]
# ### 2.2.2. Monthly

# %%
analy.monthly_stability(y=['close', 'high'], figsize=(24, 10))

# %% [markdown]
# ### 2.2.3. Daily

# %%
analy.daily_stability(y=['close', 'high'], figsize=(24, 10))

# %% [markdown]
# ## 2.3. Outlier Identification

# %% [markdown]
# ## 2.4. Distribution

# %% [markdown]
# ## 2.5. Nature Transformation Effect

# %% [markdown]
# # 3.0. Data Preparation

# %% [markdown]
# ## 3.1. Adjust Dataset

# %% [markdown]
# ## 3.2. Nature Transformation

# %% [markdown]
# # 4.0. Machine Learning Model

# %% [markdown]
# ## 4.1. SARIMAX

# %% [markdown]
# ### 4.1.1. Modeling

# %% [markdown]
# ### 4.1.2. Validation

# %% [markdown]
# ## 4.2. ARIMA

# %% [markdown]
# ### 4.2.1. Modeling

# %% [markdown]
# ### 4.2.2. Validation

# %% [markdown]
# ## 4.3. Saving Model
